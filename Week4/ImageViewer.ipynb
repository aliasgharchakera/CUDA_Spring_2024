# %% [markdown]
# <a href="https://colab.research.google.com/github/mmmovania/CUDA_Spring2023/blob/main/Week4/ImageViewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

#read image from our github repo
# !wget -nc "https://github.com/mmmovania/CUDA_Spring2023/raw/main/images/HU-LOGO--01.jpg"
# Out:
# --2023-01-28 09:36:33--  https://github.com/mmmovania/CUDA_Spring2023/raw/main/images/HU-LOGO--01.jpg
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/mmmovania/CUDA_Spring2023/main/images/HU-LOGO--01.jpg [following]
# --2023-01-28 09:36:33--  https://raw.githubusercontent.com/mmmovania/CUDA_Spring2022_GoogleColabs/main/HU-LOGO--01.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30549 (30K) [image/jpeg]
# Saving to: ‘HU-LOGO--01.jpg’
#
# HU-LOGO--01.jpg     100%[===================>]  29.83K  --.-KB/s    in 0.004s
#
# ...

# %%
#image exists, lets read it using opencv
img = cv2.imread("/content/HU-LOGO--01.jpg")

#display image using cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x143 at 0x7F442B5B8B20>
